# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: python-dotenv in ./lc-pruclarity/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: typing-extensions in ./lc-pruclarity/lib/python3.13/site-packages (from -r requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: pydantic in ./lc-pruclarity/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (2.11.7)
# Requirement already satisfied: pypdf in ./lc-pruclarity/lib/python3.13/site-packages (from -r requirements.txt (line 5)) (6.0.0)
# Requirement already satisfied: chromadb in ./lc-pruclarity/lib/python3.13/site-packages (from -r requirements.txt (line 6)) (1.0.20)
# Requirement already satisfied: requests in ./lc-pruclarity/lib/python3.13/site-packages (from -r requirements.txt (line 9)) (2.32.5)
# Requirement already satisfied: jwcrypto in ./lc-pruclarity/lib/python3.13/site-packages (from -r requirements.txt (line 10)) (1.5.6)
# Requirement already satisfied: langchain-openai in ./lc-pruclarity/lib/python3.13/site-packages (from -r requirements.txt (line 13)) (0.3.32)
# Requirement already satisfied: langgraph in ./lc-pruclarity/lib/python3.13/site-packages (from -r requirements.txt (line 14)) (0.6.6)
# Requirement already satisfied: langgraph-prebuilt in ./lc-pruclarity/lib/python3.13/site-packages (from -r requirements.txt (line 15)) (0.6.4)
# Requirement already satisfied: langchain-community in ./lc-pruclarity/lib/python3.13/site-packages (from -r requirements.txt (line 16)) (0.3.29)
# Requirement already satisfied: streamlit in ./lc-pruclarity/lib/python3.13/site-packages (from -r requirements.txt (line 19)) (1.49.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./lc-pruclarity/lib/python3.13/site-packages (from pydantic->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./lc-pruclarity/lib/python3.13/site-packages (from pydantic->-r requirements.txt (line 4)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./lc-pruclarity/lib/python3.13/site-packages (from pydantic->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: build>=1.0.3 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in ./lc-pruclarity/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 6)) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (2.3.2)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (1.36.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (1.36.0)
# Requirement already satisfied: tokenizers>=0.13.2 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (0.22.0)
# Requirement already satisfied: pypika>=0.48.9 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (7.7.0)
# Requirement already satisfied: importlib-resources in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (1.74.0)
# Requirement already satisfied: bcrypt>=4.0.1 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (0.17.3)
# Requirement already satisfied: kubernetes>=28.1.0 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (3.11.3)
# Requirement already satisfied: httpx>=0.27.0 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (14.1.0)
# Requirement already satisfied: jsonschema>=4.19.0 in ./lc-pruclarity/lib/python3.13/site-packages (from chromadb->-r requirements.txt (line 6)) (4.25.1)
# Requirement already satisfied: six>=1.5 in ./lc-pruclarity/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in ./lc-pruclarity/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in ./lc-pruclarity/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb->-r requirements.txt (line 6)) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in ./lc-pruclarity/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb->-r requirements.txt (line 6)) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./lc-pruclarity/lib/python3.13/site-packages (from requests->-r requirements.txt (line 9)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in ./lc-pruclarity/lib/python3.13/site-packages (from requests->-r requirements.txt (line 9)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./lc-pruclarity/lib/python3.13/site-packages (from requests->-r requirements.txt (line 9)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./lc-pruclarity/lib/python3.13/site-packages (from requests->-r requirements.txt (line 9)) (2025.8.3)
# Requirement already satisfied: cryptography>=3.4 in ./lc-pruclarity/lib/python3.13/site-packages (from jwcrypto->-r requirements.txt (line 10)) (45.0.7)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.74 in ./lc-pruclarity/lib/python3.13/site-packages (from langchain-openai->-r requirements.txt (line 13)) (0.3.75)
# Requirement already satisfied: openai<2.0.0,>=1.99.9 in ./lc-pruclarity/lib/python3.13/site-packages (from langchain-openai->-r requirements.txt (line 13)) (1.105.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in ./lc-pruclarity/lib/python3.13/site-packages (from langchain-openai->-r requirements.txt (line 13)) (0.11.0)
# Requirement already satisfied: langsmith>=0.3.45 in ./lc-pruclarity/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai->-r requirements.txt (line 13)) (0.4.23)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./lc-pruclarity/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai->-r requirements.txt (line 13)) (1.33)
# Requirement already satisfied: packaging>=23.2 in ./lc-pruclarity/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai->-r requirements.txt (line 13)) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./lc-pruclarity/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.74->langchain-openai->-r requirements.txt (line 13)) (3.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./lc-pruclarity/lib/python3.13/site-packages (from openai<2.0.0,>=1.99.9->langchain-openai->-r requirements.txt (line 13)) (4.10.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./lc-pruclarity/lib/python3.13/site-packages (from openai<2.0.0,>=1.99.9->langchain-openai->-r requirements.txt (line 13)) (0.10.0)
# Requirement already satisfied: sniffio in ./lc-pruclarity/lib/python3.13/site-packages (from openai<2.0.0,>=1.99.9->langchain-openai->-r requirements.txt (line 13)) (1.3.1)
# Requirement already satisfied: httpcore==1.* in ./lc-pruclarity/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 6)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./lc-pruclarity/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb->-r requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: regex>=2022.1.18 in ./lc-pruclarity/lib/python3.13/site-packages (from tiktoken<1,>=0.7->langchain-openai->-r requirements.txt (line 13)) (2025.9.1)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in ./lc-pruclarity/lib/python3.13/site-packages (from langgraph->-r requirements.txt (line 14)) (2.1.1)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in ./lc-pruclarity/lib/python3.13/site-packages (from langgraph->-r requirements.txt (line 14)) (0.2.5)
# Requirement already satisfied: xxhash>=3.5.0 in ./lc-pruclarity/lib/python3.13/site-packages (from langgraph->-r requirements.txt (line 14)) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in ./lc-pruclarity/lib/python3.13/site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph->-r requirements.txt (line 14)) (1.10.0)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in ./lc-pruclarity/lib/python3.13/site-packages (from langchain-community->-r requirements.txt (line 16)) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./lc-pruclarity/lib/python3.13/site-packages (from langchain-community->-r requirements.txt (line 16)) (2.0.43)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./lc-pruclarity/lib/python3.13/site-packages (from langchain-community->-r requirements.txt (line 16)) (3.12.15)
# Requirement already satisfied: dataclasses-json<0.7,>=0.6.7 in ./lc-pruclarity/lib/python3.13/site-packages (from langchain-community->-r requirements.txt (line 16)) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in ./lc-pruclarity/lib/python3.13/site-packages (from langchain-community->-r requirements.txt (line 16)) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in ./lc-pruclarity/lib/python3.13/site-packages (from langchain-community->-r requirements.txt (line 16)) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./lc-pruclarity/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 16)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./lc-pruclarity/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 16)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./lc-pruclarity/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 16)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./lc-pruclarity/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 16)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./lc-pruclarity/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 16)) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in ./lc-pruclarity/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 16)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./lc-pruclarity/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 16)) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./lc-pruclarity/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community->-r requirements.txt (line 16)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./lc-pruclarity/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community->-r requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in ./lc-pruclarity/lib/python3.13/site-packages (from langchain<2.0.0,>=0.3.27->langchain-community->-r requirements.txt (line 16)) (0.3.11)
# Requirement already satisfied: greenlet>=1 in ./lc-pruclarity/lib/python3.13/site-packages (from SQLAlchemy<3,>=1.4->langchain-community->-r requirements.txt (line 16)) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./lc-pruclarity/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain-community->-r requirements.txt (line 16)) (1.1.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in ./lc-pruclarity/lib/python3.13/site-packages (from streamlit->-r requirements.txt (line 19)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in ./lc-pruclarity/lib/python3.13/site-packages (from streamlit->-r requirements.txt (line 19)) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in ./lc-pruclarity/lib/python3.13/site-packages (from streamlit->-r requirements.txt (line 19)) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in ./lc-pruclarity/lib/python3.13/site-packages (from streamlit->-r requirements.txt (line 19)) (8.2.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in ./lc-pruclarity/lib/python3.13/site-packages (from streamlit->-r requirements.txt (line 19)) (2.3.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in ./lc-pruclarity/lib/python3.13/site-packages (from streamlit->-r requirements.txt (line 19)) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in ./lc-pruclarity/lib/python3.13/site-packages (from streamlit->-r requirements.txt (line 19)) (6.32.0)
# Requirement already satisfied: pyarrow>=7.0 in ./lc-pruclarity/lib/python3.13/site-packages (from streamlit->-r requirements.txt (line 19)) (21.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in ./lc-pruclarity/lib/python3.13/site-packages (from streamlit->-r requirements.txt (line 19)) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in ./lc-pruclarity/lib/python3.13/site-packages (from streamlit->-r requirements.txt (line 19)) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in ./lc-pruclarity/lib/python3.13/site-packages (from streamlit->-r requirements.txt (line 19)) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in ./lc-pruclarity/lib/python3.13/site-packages (from streamlit->-r requirements.txt (line 19)) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in ./lc-pruclarity/lib/python3.13/site-packages (from streamlit->-r requirements.txt (line 19)) (6.5.2)
# Requirement already satisfied: jinja2 in ./lc-pruclarity/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 19)) (3.1.6)
# Requirement already satisfied: narwhals>=1.14.2 in ./lc-pruclarity/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 19)) (2.3.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./lc-pruclarity/lib/python3.13/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 19)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./lc-pruclarity/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 19)) (5.0.2)
# Requirement already satisfied: pytz>=2020.1 in ./lc-pruclarity/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 19)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./lc-pruclarity/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 19)) (2025.2)
# Requirement already satisfied: pyproject_hooks in ./lc-pruclarity/lib/python3.13/site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in ./lc-pruclarity/lib/python3.13/site-packages (from cryptography>=3.4->jwcrypto->-r requirements.txt (line 10)) (1.17.1)
# Requirement already satisfied: pycparser in ./lc-pruclarity/lib/python3.13/site-packages (from cffi>=1.14->cryptography>=3.4->jwcrypto->-r requirements.txt (line 10)) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in ./lc-pruclarity/lib/python3.13/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 19)) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./lc-pruclarity/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb->-r requirements.txt (line 6)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in ./lc-pruclarity/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb->-r requirements.txt (line 6)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./lc-pruclarity/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb->-r requirements.txt (line 6)) (0.27.1)
# Requirement already satisfied: google-auth>=1.0.1 in ./lc-pruclarity/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./lc-pruclarity/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in ./lc-pruclarity/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in ./lc-pruclarity/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in ./lc-pruclarity/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (0.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./lc-pruclarity/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./lc-pruclarity/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in ./lc-pruclarity/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (0.6.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./lc-pruclarity/lib/python3.13/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai->-r requirements.txt (line 13)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./lc-pruclarity/lib/python3.13/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai->-r requirements.txt (line 13)) (0.24.0)
# Requirement already satisfied: coloredlogs in ./lc-pruclarity/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (15.0.1)
# Requirement already satisfied: flatbuffers in ./lc-pruclarity/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (25.2.10)
# Requirement already satisfied: sympy in ./lc-pruclarity/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in ./lc-pruclarity/lib/python3.13/site-packages (from opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 6)) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in ./lc-pruclarity/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 6)) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in ./lc-pruclarity/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 6)) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.36.0 in ./lc-pruclarity/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 6)) (1.36.0)
# Requirement already satisfied: opentelemetry-proto==1.36.0 in ./lc-pruclarity/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 6)) (1.36.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in ./lc-pruclarity/lib/python3.13/site-packages (from opentelemetry-sdk>=1.2.0->chromadb->-r requirements.txt (line 6)) (0.57b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./lc-pruclarity/lib/python3.13/site-packages (from rich>=10.11.0->chromadb->-r requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./lc-pruclarity/lib/python3.13/site-packages (from rich>=10.11.0->chromadb->-r requirements.txt (line 6)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./lc-pruclarity/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->-r requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in ./lc-pruclarity/lib/python3.13/site-packages (from tokenizers>=0.13.2->chromadb->-r requirements.txt (line 6)) (0.34.4)
# Requirement already satisfied: filelock in ./lc-pruclarity/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->-r requirements.txt (line 6)) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in ./lc-pruclarity/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->-r requirements.txt (line 6)) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./lc-pruclarity/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->-r requirements.txt (line 6)) (1.1.9)
# Requirement already satisfied: shellingham>=1.3.0 in ./lc-pruclarity/lib/python3.13/site-packages (from typer>=0.9.0->chromadb->-r requirements.txt (line 6)) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in ./lc-pruclarity/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 6)) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in ./lc-pruclarity/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 6)) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in ./lc-pruclarity/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in ./lc-pruclarity/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 6)) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in ./lc-pruclarity/lib/python3.13/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./lc-pruclarity/lib/python3.13/site-packages (from sympy->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from typing import Annotated
from typing import Literal
from typing_extensions import TypedDict

from langgraph.prebuilt import create_react_agent
from langgraph.graph import StateGraph, MessagesState, START, END
from langchain_openai import ChatOpenAI
from langgraph.types import Command
from IPython.display import Image,display

model = ChatOpenAI(
    model="gpt-3.5-turbo",  
    temperature=0,
    max_tokens=4000,
)

# %%
import os
from PyPDF2 import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma

PDF_FOLDER = "./docs"
CHUNK_SIZE, CHUNK_OVERLAP, TOP_K = 1000, 200, 1
VECTORSTORE_CACHE = "./vectorstore_cache"

# --- Load or build vectorstore ---
if os.path.exists(VECTORSTORE_CACHE):
    # Load cached vectorstore
    embeddings = OpenAIEmbeddings()
    vectorstore = Chroma(persist_directory=VECTORSTORE_CACHE, embedding_function=embeddings)
    print("[INFO] Loaded cached vectorstore.")
else:
    # Read all PDFs in folder
    docs = []
    for filename in os.listdir(PDF_FOLDER):
        if filename.lower().endswith(".pdf"):
            pdf_path = os.path.join(PDF_FOLDER, filename)
            text = "\n".join(page.extract_text() or "" for page in PdfReader(pdf_path).pages)
            if text.strip():
                docs.append(text)

    full_text = "\n".join(docs)
    print(f"[INFO] Total PDFs read: {len(docs)}")

    # Split into chunks
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=CHUNK_SIZE,
        chunk_overlap=CHUNK_OVERLAP
    )
    chunks = text_splitter.split_text(full_text)
    print(f"[INFO] Total chunks created: {len(chunks)}")

    # Build vectorstore and persist
    embeddings = OpenAIEmbeddings()
    vectorstore = Chroma.from_texts(chunks, embeddings, persist_directory=VECTORSTORE_CACHE)
    vectorstore.persist()
    print("[INFO] Vectorstore created and cached.")

# --- Create retriever ---
retriever = vectorstore.as_retriever(search_kwargs={"k": TOP_K})
print(f"[INFO] Retriever ready. Top-{TOP_K} chunks per query.")
# Out:
# /tmp/ipykernel_186250/1766990259.py:15: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vectorstore = Chroma(persist_directory=VECTORSTORE_CACHE, embedding_function=embeddings)
# [INFO] Loaded cached vectorstore.
# [INFO] Retriever ready. Top-1 chunks per query.

# %%
from typing import TypedDict, List, Dict, Any, Literal
from langchain_openai import ChatOpenAI
from langgraph.types import Command
from langgraph.graph import StateGraph, MessagesState, START, END
from langchain.prompts import PromptTemplate
import json

class PersonFeatures(TypedDict):
    age: int
    marital: str
    dependents: int
    children_ages: List[int]
    income: float
    cpf_balance: float
    housing_type: str
    has_dependents: bool

class LifeStage(TypedDict):
    stage_name: str
    age_range: str
    features: Dict[str, Any]

class ShieldPlanRecommendation(TypedDict):
    plan_name: str
    hospital_class: str
    annual_coverage_limit: str
    panel_doctors: str
    waiting_time: str
    access_to_treatment: str
    out_of_pocket_cost: Dict[str, Any]
    suitable_for: List[str]
    reason: str
    projected_life_stage: List[str]

class ClientState(TypedDict):
    sections: List[Dict[str, Any]]
    life_stages: List[LifeStage]
    shield_plan_recommendations: List[ShieldPlanRecommendation]
    summary: str

# %%
def supervisor(state: dict) -> Command[Literal["agent_1", "agent_2", END]]:
    if not state.get("life_stages", []):  # check empty list too
        return Command(goto="agent_1")
    if not state.get("shield_plan_recommendations", []):  # same here
        return Command(goto="agent_2")
    return Command(goto=END)

import json

def agent_1(state: dict) -> Command[Literal["supervisor"]]:
    sections = state.get("sections", [])  # <-- corrected key
    prompt = f"""
    Based on the following client features:
    {json.dumps(sections)}

    Generate up to 5 life stages for this client, spanning from their current age to retirement. Each life stage should reflect realistic changes in marital status, dependents, income, career progression, and other relevant personal or financial circumstances. Output only structured JSON objects with stage_name, age_range, and features.

    Output ONLY a JSON array of  LifeStage objects with growth in mind.
    Each LifeStage object must include:
    - stage_name
    - age_range
    - features (dict)
    """
    life_stages = []
    try:
        response = model.invoke(prompt).content.strip()
        if response:
            life_stages = json.loads(response)
            if not isinstance(life_stages, list):
                life_stages = []
            else:
                life_stages = [s for s in life_stages if isinstance(s, dict)]
    except Exception as e:
        print("Agent_1 JSON error:", e, "Raw response:", response)

    return Command(goto="supervisor", update={"life_stages": life_stages})


def agent_2(state: dict) -> Command[Literal["supervisor"]]:
    life_stages = state.get("life_stages", [])
    if not life_stages:
        return Command(goto="supervisor", update={"shield_plan_recommendations": {"ShieldPlanRecommendation": []}})

    query_text = json.dumps(life_stages)
    docs = retriever.invoke(query_text)  # returns list of Document objects
    knowledge_text = "\n".join(d.page_content for d in docs[:3])
    prompt = f"""
    Using the knowledge base below and or online, recommend any PRUShield plans and PRUExtra Copay supplementary plans tailored to the client’s life stages.

    Knowledge Base:
    {knowledge_text}

    Client life stages:
    {json.dumps(life_stages)}

    Instructions:
    Generate a JSON array of ShieldPlanRecommendation objects for each life stage objects.
    Each object must include the following fields:
    - plan_name
    - hospital_class
    - annual_coverage_limit
    - panel_doctors
    - waiting_time
    - access_to_treatment
    - out_of_pocket_cost
    - suitable_for
    - reason
    - projected_life_stage
    Consider each life stage carefully and provide recommendations tailored to the client’s age, marital status, dependents, income, and other relevant features.
    Output strictly valid JSON. Do not include any explanation, comments, or text outside the JSON array.
    """

    recommendations = []
    try:
        response = model.invoke(prompt).content
        recommendations = json.loads(response)

        # wrap in expected dict key
        recommendations = {"ShieldPlanRecommendation": recommendations}

    except Exception as e:
        print("Agent_2 JSON error:", e)
        recommendations = {"ShieldPlanRecommendation": []}

    return Command(goto="supervisor", update={"shield_plan_recommendations": recommendations})

# %%
builder = StateGraph(ClientState)
builder.add_node(supervisor)
builder.add_node(agent_1)
builder.add_node(agent_2)
builder.add_edge(START, "supervisor")
supervisor_system = builder.compile()

# %%
from typing import TypedDict, List, Dict, Any
from datetime import datetime, date
import requests

def extract_features(data: dict) -> PersonFeatures:
    today = date.today()
    
    # Age
    dob_str = data.get("dob", {}).get("value")
    age = 0
    if dob_str:
        try:
            dob = datetime.strptime(dob_str, "%Y-%m-%d")
            age = today.year - dob.year - ((today.month, today.day) < (dob.month, dob.day))
        except ValueError:
            pass

    # Children ages
    children = data.get("childrenbirthrecords", [])
    children_ages = []
    for child in children:
        child_dob_str = child.get("dob", {}).get("value") or child.get("dob")
        if child_dob_str:
            try:
                child_dob = datetime.strptime(child_dob_str, "%Y-%m-%d")
                child_age = today.year - child_dob.year - ((today.month, today.day) < (child_dob.month, child_dob.day))
                children_ages.append(child_age)
            except ValueError:
                continue

    # Income
    noas = data.get("noahistory", {}).get("noas", [])
    income = float(noas[-1]["amount"]["value"]) if noas else 0.0

    # CPF
    cpf = data.get("cpfbalances", {})
    cpf_balance = sum(float(cpf.get(k, {}).get("value", 0)) for k in ("oa", "sa", "ma", "ra"))

    # Marital and housing
    marital = data.get("marital", {}).get("desc", "Unknown")
    housing_type = data.get("hdbtype", {}).get("desc", "")

    return {
        "age": age,
        "marital": marital,
        "dependents": len(children),
        "children_ages": children_ages,
        "income": income,
        "cpf_balance": cpf_balance,
        "housing_type": housing_type,
        "has_dependents": bool(children_ages)
    }

# --- Fetch sample data and build client state ---
url = "https://sandbox.api.myinfo.gov.sg/com/v4/person-sample/S9812381D"
data = requests.get(url).json()
features = extract_features(data)

# --- Initialize ClientState ---
client_state: ClientState = {
    "sections": [features],  # wrap features in a list
    "life_stages": [],       # populate from Agent_1
    "shield_plan_recommendations": [],  # populate from Agent_2
    "summary": ""
}
print(json.dumps(client_state, indent=4))
# Out:
# {
#     "sections": [
#         {
#             "age": 27,
#             "marital": "MARRIED",
#             "dependents": 1,
#             "children_ages": [
#                 7
#             ],
#             "income": 53700.0,
#             "cpf_balance": 94655.25,
#             "housing_type": "3-ROOM FLAT (HDB)",
#             "has_dependents": true
#         }
#     ],
#     "life_stages": [],
#     "shield_plan_recommendations": [],
#     "summary": ""
# }

# %%
finalresult = supervisor_system.invoke(client_state)
final_json = (json.dumps(finalresult, indent=4))
print(final_json)
# Out:
# {
#     "sections": [
#         {
#             "age": 27,
#             "marital": "MARRIED",
#             "dependents": 1,
#             "children_ages": [
#                 7
#             ],
#             "income": 53700.0,
#             "cpf_balance": 94655.25,
#             "housing_type": "3-ROOM FLAT (HDB)",
#             "has_dependents": true
#         }
#     ],
#     "life_stages": [
#         {
#             "stage_name": "Early Career",
#             "age_range": "27-35",
#             "features": {
#                 "marital": "MARRIED",
#                 "dependents": 1,
#                 "children_ages": [
#                     7
#                 ],
#                 "income": 60000.0,
#                 "cpf_balance": 100000.0,
#                 "housing_type": "3-ROOM FLAT (HDB)",
#                 "has_dependents": true
#             }
#         },
#         {
#             "stage_name": "Mid Career",
#             "age_range": "36-45",
#             "features": {
#                 "marital": "MARRIED",
#                 "dependents": 2,
#                 "children_ages": [
#                     7,
#                     15
#                 ],
#                 "income": 75000.0,
#                 "cpf_balance": 120000.0,
#                 "housing_type": "4-ROOM FLAT (HDB)",
#                 "has_dependents": true
#             }
#         },
#         {
#             "stage_name": "Peak Career",
#             "age_range": "46-55",
#             "features": {
#                 "marital": "MARRIED",
#                 "dependents": 2,
#                 "children_ages": [
#                     15,
#                     23
#                 ],
#                 "income": 90000.0,
#                 "cpf_balance": 150000.0,
#                 "housing_type": "PRIVATE PROPERTY",
#                 "has_dependents": true
#             }
#         },
#         {
#             "stage_name": "Pre-Retirement",
#             "age_range": "56-65",
#             "features": {
#                 "marital": "MARRIED",
#                 "dependents": 2,
#                 "children_ages": [
#                     23,
#                     31
#                 ],
#                 "income": 80000.0,
#                 "cpf_balance": 180000.0,
#                 "housing_type": "PRIVATE PROPERTY",
#                 "has_dependents": true
#             }
#         },
#         {
#             "stage_name": "Retirement",
#             "age_range": "66+",
#             "features": {
#                 "marital": "MARRIED",
#                 "dependents": 2,
#                 "children_ages": [
#                     31,
#                     39
#                 ],
#                 "income": 60000.0,
#                 "cpf_balance": 200000.0,
#                 "housing_type": "PRIVATE PROPERTY",
#                 "has_dependents": true
#             }
#         }
#     ],
#     "shield_plan_recommendations": {
#         "ShieldPlanRecommendation": [
#             {
#                 "plan_name": "PRUShield Standard",
#                 "hospital_class": "Class B1",
#                 "annual_coverage_limit": 1500.0,
#                 "panel_doctors": "Yes",
#                 "waiting_time": "30 days",
#                 "access_to_treatment": "Private hospitals and restructured hospitals",
#                 "out_of_pocket_cost": 907.0,
#                 "suitable_for": "Early Career",
#                 "reason": "Affordable coverage for young families with one dependent",
#                 "projected_life_stage": "Early Career"
#             },
#             {
#                 "plan_name": "PRUExtra Copay 10",
#                 "hospital_class": "Class B1",
#                 "annual_coverage_limit": 600.0,
#                 "panel_doctors": "Yes",
#                 "waiting_time": "30 days",
#                 "access_to_treatment": "Private hospitals and restructured hospitals",
#                 "out_of_pocket_cost": 343.0,
#                 "suitable_for": "Early Career",
#                 "reason": "Additional coverage for outpatient treatments at a lower cost",
#                 "projected_life_stage": "Early Career"
#             },
#             {
#                 "plan_name": "PRUShield Plus",
#                 "hospital_class": "Class A",
#                 "annual_coverage_limit": 1735.0,
#                 "panel_doctors": "Yes",
#                 "waiting_time": "30 days",
#                 "access_to_treatment": "Private hospitals and restructured hospitals",
#                 "out_of_pocket_cost": 1135.0,
#                 "suitable_for": "Mid Career",
#                 "reason": "Comprehensive coverage for families with two dependents",
#                 "projected_life_stage": "Mid Career"
#             },
#             {
#                 "plan_name": "PRUExtra Copay 10",
#                 "hospital_class": "Class A",
#                 "annual_coverage_limit": 600.0,
#                 "panel_doctors": "Yes",
#                 "waiting_time": "30 days",
#                 "access_to_treatment": "Private hospitals and restructured hospitals",
#                 "out_of_pocket_cost": 343.0,
#                 "suitable_for": "Mid Career",
#                 "reason": "Additional coverage for outpatient treatments at a lower cost",
#                 "projected_life_stage": "Mid Career"
#             },
#             {
#                 "plan_name": "PRUShield Premier",
#                 "hospital_class": "As Charged",
#                 "annual_coverage_limit": 1855.0,
#                 "panel_doctors": "Yes",
#                 "waiting_time": "30 days",
#                 "access_to_treatment": "Private hospitals and restructured hospitals",
#                 "out_of_pocket_cost": 1255.0,
#                 "suitable_for": "Peak Career",
#                 "reason": "High coverage for families with older dependents",
#                 "projected_life_stage": "Peak Career"
#             },
#             {
#                 "plan_name": "PRUExtra Copay 10",
#                 "hospital_class": "As Charged",
#                 "annual_coverage_limit": 600.0,
#                 "panel_doctors": "Yes",
#                 "waiting_time": "30 days",
#                 "access_to_treatment": "Private hospitals and restructured hospitals",
#                 "out_of_pocket_cost": 343.0,
#                 "suitable_for": "Peak Career",
#                 "reason": "Additional coverage for outpatient treatments at a lower cost",
#                 "projected_life_stage": "Peak Career"
#             },
#             {
#                 "plan_name": "PRUShield Plus",
#                 "hospital_class": "As Charged",
#                 "annual_coverage_limit": 2064.0,
#                 "panel_doctors": "Yes",
#                 "waiting_time": "30 days",
#                 "access_to_treatment": "Private hospitals and restructured hospitals",
#                 "out_of_pocket_cost": 1464.0,
#                 "suitable_for": "Pre-Retirement",
#                 "reason": "Comprehensive coverage for families approaching retirement",
#                 "projected_life_stage": "Pre-Retirement"
#             },
#             {
#                 "plan_name": "PRUExtra Copay 10",
#                 "hospital_class": "As Charged",
#                 "annual_coverage_limit": 600.0,
#                 "panel_doctors": "Yes",
#                 "waiting_time": "30 days",
#                 "access_to_treatment": "Private hospitals and restructured hospitals",
#                 "out_of_pocket_cost": 343.0,
#                 "suitable_for": "Pre-Retirement",
#                 "reason": "Additional coverage for outpatient treatments at a lower cost",
#                 "projected_life_stage": "Pre-Retirement"
#             },
#             {
#                 "plan_name": "PRUShield Premier",
#                 "hospital_class": "As Charged",
#                 "annual_coverage_limit": 2737.0,
#                 "panel_doctors": "Yes",
#                 "waiting_time": "30 days",
#                 "access_to_treatment": "Private hospitals and restructured hospitals",
#                 "out_of_pocket_cost": 2137.0,
#                 "suitable_for": "Retirement",
#                 "reason": "High coverage for families in retirement",
#                 "projected_life_stage": "Retirement"
#             },
#             {
#                 "plan_name": "PRUExtra Copay 10",
#                 "hospital_class": "As Charged",
#                 "annual_coverage_limit": 600.0,
#                 "panel_doctors": "Yes",
#                 "waiting_time": "30 days",
#                 "access_to_treatment": "Private hospitals and restructured hospitals",
#                 "out_of_pocket_cost": 343.0,
#                 "suitable_for": "Retirement",
#                 "reason": "Additional coverage for outpatient treatments at a lower cost",
#                 "projected_life_stage": "Retirement"
#             }
#         ]
#     },
#     "summary": ""
# }

# %%
import json

with open("result.json", "w") as f:
    json.dump(finalresult, f)

# %%
# !streamlit run app.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.0.92:8501
